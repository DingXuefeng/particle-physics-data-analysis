# %%
print('hi')
# Out:
# hi

# %%
# !pip install jupyter matplotlib pandas numpy scipy mplhep uproot pyarrow iminuit
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: jupyter in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (1.0.0)
# Collecting matplotlib
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3d/44/c4218d351df907c9a39add2d93594ede085a6dc53b5760c67f1eca7871bf/matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.5 MB/s eta 0:00:0000:0100:01
# Collecting pandas
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/db/7c/9a60add21b96140e22465d9adf09832feade45235cd22f4cb1668a25e443/pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 77.2 MB/s eta 0:00:00 0:00:01m
# Collecting numpy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3f/ab/1dc9f176d3084a2546cf76eb213dc61586d015ef59b3b17947b0e40038af/numpy-2.0.0-cp312-cp312-macosx_14_0_arm64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 88.0 MB/s eta 0:00:00ta 0:00:01
# Collecting scipy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/09/70/5e756d3f90fe3fff64d1550db0fa6bb9eb76eedd084c568618f93441f08c/scipy-1.14.0-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 83.3 MB/s eta 0:00:0000:0100:01
# Collecting mplhep
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b3/e7/f311776e49589009e67906dbc022696b67ce9a69bd24172673f1991ca719/mplhep-0.3.50-py3-none-any.whl (39 kB)
# Collecting uproot
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/53/f0/71e22dca1eeadc60f5c7034d9e38efd8970a2c69d334d7653dc0bf7f76d1/uproot-5.3.10-py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.5/352.5 kB 35.1 MB/s eta 0:00:00
# Collecting pyarrow
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8e/0a/dbd0c134e7a0c30bea439675cc120012337202e5fac7163ba839aa3691d2/pyarrow-17.0.0-cp312-cp312-macosx_11_0_arm64.whl (27.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 79.7 MB/s eta 0:00:0000:0100:01
# Collecting iminuit
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/58/68/ddb28c659fa2d0cc62260cccda0952843c802959197b17e24ef08bedc1de/iminuit-2.26.0-cp312-cp312-macosx_11_0_arm64.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.5/362.5 kB 33.7 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (7.2.1)
# Requirement already satisfied: qtconsole in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter) (8.1.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/51/03/36ecc6fd1d018336625ad91b91fd34cd9ba8da5d36f5e1167dfe3275070a/contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 32.9 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/dd/bd/cb8fd2dddd68089c112bf42a88afe188b8ace73f94406539857dcc9347a6/fonttools-4.53.1-cp312-cp312-macosx_11_0_arm64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/26/61/58bb691f6880588be3a4801d199bd776032ece07203faf3e4a8b377f7d9b/kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e7/cf/5c558a0f247e0bf9cec92bff9b46ae6474dd736f6d906315e60e4075f737/pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.1 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 43.9 MB/s eta 0:00:00
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 37.1 MB/s eta 0:00:00
# Collecting mplhep-data (from mplhep)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b9/f2/97faf68c79fc135061190092e8e6db9a024de4249a7e82acc83d9443db2b/mplhep_data-0.0.3-py3-none-any.whl (5.8 MB)
# Collecting uhi>=0.2.0 (from mplhep)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/2a/9a/d5de1ec139e24f0f8d9e1b9cfdf6b3ade0d0d204f99b20ff921472206b91/uhi-0.4.0-py3-none-any.whl (11 kB)
# Collecting awkward>=2.4.6 (from uproot)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/eb/7f/88a1dc2c5212b4c2770d06a3c205dfec10a2ad9415157041ca5836b4d90e/awkward-2.6.6-py3-none-any.whl (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.5/812.5 kB 49.9 MB/s eta 0:00:00
# Collecting cramjam>=2.5.0 (from uproot)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ec/50/87d0f705401d6a754bcde63d2f1daaa2822935114a09f103fd885ae8ca3a/cramjam-2.8.3-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 91.0 MB/s eta 0:00:00:00:01
# Collecting fsspec (from uproot)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5e/44/73bea497ac69bafde2ee4269292fa3b41f1198f4bb7bbaaabde30ad29d4a/fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 23.0 MB/s eta 0:00:00
# Collecting awkward-cpp==35 (from awkward>=2.4.6->uproot)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1e/67/ed276f9209040ba6489fc2ce7875038719b8ded4806b57da1429475623e7/awkward_cpp-35-cp312-cp312-macosx_10_9_universal2.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: appnope in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: pygments in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from notebook->jupyter) (4.2.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: webencodings in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (70.2.0)
# Requirement already satisfied: babel>=2.10 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: requests>=2.31 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: certifi in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/dingxf/work/dingxf/software/python-venv/gastpcsw/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Installing collected packages: pytz, tzdata, pyparsing, pillow, numpy, mplhep-data, kiwisolver, fsspec, fonttools, cycler, cramjam, uhi, scipy, pyarrow, pandas, iminuit, contourpy, awkward-cpp, matplotlib, awkward, uproot, mplhep
# Successfully installed awkward-2.6.6 awkward-cpp-35 contourpy-1.2.1 cramjam-2.8.3 cycler-0.12.1 fonttools-4.53.1 fsspec-2024.6.1 iminuit-2.26.0 kiwisolver-1.4.5 matplotlib-3.9.1 mplhep-0.3.50 mplhep-data-0.0.3 numpy-2.0.0 pandas-2.2.2 pillow-10.4.0 pyarrow-17.0.0 pyparsing-3.1.2 pytz-2024.1 scipy-1.14.0 tzdata-2024.1 uhi-0.4.0 uproot-5.3.10
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# basic setup of the notebook
from matplotlib import pyplot as plt
import numpy as np

# everything in iminuit is done through the Minuit object, so we import it
from iminuit import Minuit

# we also need a cost function to fit and import the LeastSquares function
from iminuit.cost import LeastSquares

# display iminuit version
import iminuit
print("iminuit version:", iminuit.__version__)
# our line model, unicode parameter names are supported :)
def line(x, α, β):
    return α + x * β


# generate random toy data with random offsets in y
rng = np.random.default_rng(1)
data_x = np.linspace(0, 1, 10)
data_yerr = 0.1  # could also be an array
data_y = rng.normal(line(data_x, 1, 2), data_yerr)
least_squares = LeastSquares(data_x, data_y, data_yerr, line)

m = Minuit(least_squares, α=0, β=0)  # starting values for α and β

m.migrad()  # finds minimum of least_squares function
m.hesse()   # accurately computes uncertainties
# Out:
# Matplotlib is building the font cache; this may take a moment.
# iminuit version: 2.26.0
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 3.959 (χ²/ndof = 0.5)      │              Nfcn = 46               │
# │ EDM = 3.1e-23 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬──────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼──────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ α    │   1.02    │   0.06    │            │            │         │         │       │
# │ 1 │ β    │    2.0    │    0.1    │            │            │         │         │       │
# └───┴──────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌───┬─────────────────┐
# │   │       α       β │
# ├───┼─────────────────┤
# │ α │ 0.00345 -0.0049 │
# │ β │ -0.0049 0.00982 │
# └───┴─────────────────┘
